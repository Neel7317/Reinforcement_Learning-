# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (1.6.2)
# Requirement already satisfied: numpy in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (1.18.5)
# Requirement already satisfied: pandas in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (1.3.4)
# Requirement already satisfied: gym==0.21 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: cloudpickle in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (3.5.0)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: torch>=1.11 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (1.12.0)
# Requirement already satisfied: opencv-python in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (4.5.5.64)
# Requirement already satisfied: psutil in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (5.9.1)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (2.10.1)
# Requirement already satisfied: rich in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (12.5.1)
# Requirement already satisfied: pillow in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (8.4.0)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: importlib-resources in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.4.0)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.25.1)
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.1.3)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\appdata\roaming\python\python37\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (4.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.42.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (58.5.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dell\appdata\roaming\python\python37\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.28.1)
# WARNING: Ignoring invalid distribution -udenet (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -udenet (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -udenet (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -udenet (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python37\lib\site-packages)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from rich->stable-baselines3[extra]) (2.10.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: six in c:\users\dell\appdata\roaming\python\python37\site-packages (from absl-py>=0.4->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\roaming\python\python37\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\appdata\roaming\python\python37\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\dell\appdata\roaming\python\python37\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\appdata\roaming\python\python37\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\roaming\python\python37\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\roaming\python\python37\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from setuptools-scm>=4->matplotlib->stable-baselines3[extra]) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\appdata\roaming\python\python37\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.1)

# %%
import torch
torch.__version__
# Out:
# '1.12.0+cpu'

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:35.0
# Episode:2 Score:12.0
# Episode:3 Score:31.0
# Episode:4 Score:11.0
# Episode:5 Score:13.0

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 0

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([ 3.2211461e+00,  1.4214151e+38, -4.0755153e-01,  1.1587895e+38],
#       dtype=float32)

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1524 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008781649 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.00449     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.28        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 51.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009981254 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 35.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 745        |
# |    iterations           | 4          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00864588 |
# |    clip_fraction        | 0.0936     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.635     |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.3       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0211    |
# |    value_loss           | 52.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0104633495 |
# |    clip_fraction        | 0.0829       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0182      |
# |    value_loss           | 58.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006192592 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00953    |
# |    value_loss           | 66.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 7            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0072594574 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0076      |
# |    value_loss           | 51           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 8            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0039348877 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 46.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 9           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007952482 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.88        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.002223372 |
# |    clip_fraction        | 0.00493     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.791       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.000361    |
# |    value_loss           | 13.8        |
# -----------------------------------------

# %%
import os

# %%
model.save(PPO_path)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'Training\Saved model' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
pwd
# Out:
# 'C:\\Users\\DELL'

# %%
del model

# %%
model = PPO.load('C:\\Users\\DELL\\Training\\Saved model\\PPO_model', env=env)

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (200.0, 0.0)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([-0.1134868 ,  1.122234  ,  0.07492612, -0.7116332 ], dtype=float32)}]

# %%
env.close()

# %%
log_path='Traning\\Logs\\'
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
training_log_path
# Out:
# 'Traning\\Logs\\PPO_3'

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
save_path = os.path.join('Training', 'Saved Model')

# %%
save_path
# Out:
# 'Training\\Saved Model'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Traning\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 231  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008984496 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.000878   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.17        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 53.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010366511 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0895      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008614295 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 51.4        |
# -----------------------------------------
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009734613 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 66.2        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 190

# %%
model_path = os.path.join('Training', 'Saved Model', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (200.0, 0.0)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'terminal_observation': array([-2.4203959 , -2.1580534 , -0.20546779, -0.32316166], dtype=float32)}]

# %%
env.close()

# %%
from stable_baselines3 import DQN
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
model.learn(total_timesteps=20000, callback=eval_callback)
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')
model.save(dqn_path)
# Out:
# Using cpu device
# Logging to Traning\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3392     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3547     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3523     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 229      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3489     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3316     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 388      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 463      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3407     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3521     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3641     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 761      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3712     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 865      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3841     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 972      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3871     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4013     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4032     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.366    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4006     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4049     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4099     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4077     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4109     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.168    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4110     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4090     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0942   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4048     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4073     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4070     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4095     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4095     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4129     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4126     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4170     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4200     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4244     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4279     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4287     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4323     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4363     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4397     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4427     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4464     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4482     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4501     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 